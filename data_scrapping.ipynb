# %%
# Import libraris
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import json
import os
import numpy as np
from requests.models import MissingSchema
import trafilatura

# %%
base_url = 'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/'
page_source = requests.get(base_url)
soup = BeautifulSoup(page_source.content, 'html.parser',from_encoding="utf-8")

# %%
# Define Function for data extraction
def beautifulsoup_extract_text_fallback(response_content):
    
    '''
    This is a fallback function, so that we can always return a value for text content.
    Even for when both Trafilatura and BeautifulSoup are unable to extract the text from a 
    single URL.
    '''
    
    # Create the beautifulsoup object:
    soup = BeautifulSoup(response_content, 'html.parser',from_encoding="utf-8")
    
    # Finding the text:
    text = soup.find_all(text=True)

    # Remove unwanted tag elements:
    cleaned_text = ''
    blacklist = [
        '[document]',
        'noscript',
        'header',
        'html',
        'meta',
        'head', 
        'input',
        'script',
        'style',]

    # Then we will loop over every item in the extract text and make sure that the beautifulsoup4 tag
    # is NOT in the blacklist
    for item in text:
        if item.parent.name not in blacklist:
            cleaned_text += '{} '.format(item)
            
    # Remove any tab separation and strip the text:
    cleaned_text = cleaned_text.replace('\t', '')
    cleaned_text = re.sub(r"[^a-z A-Z 0-9$£]","",cleaned_text)
    return cleaned_text.strip()
    

def extract_text_from_single_web_page(url):
    
    downloaded_url = trafilatura.fetch_url(url)
    try:
        a = trafilatura.extract(downloaded_url, include_links=True,deduplicate=True,output_format='json', with_metadata=True, include_comments = False,
                            date_extraction_params={'extensive_search': True, 'original_date': True})
    except AttributeError:
        a = trafilatura.extract(downloaded_url, include_links=True,deduplicate=True,output_format='json', with_metadata=True,
                            date_extraction_params={'extensive_search': True, 'original_date': True})
    if a:
        json_output = json.loads(a)
        return json_output['text']
    else:
        try:
            resp = requests.get(url)
            # We will only extract the text from successful requests:
            if resp.status_code == 200:
                return beautifulsoup_extract_text_fallback(resp.content)
            else:
                # This line will handle for any failures in both the Trafilature and BeautifulSoup4 functions:
                return np.nan
        # Handling for any URLs that don't have the correct protocol
        except MissingSchema:
            return np.nan

# %%
# Collect all urls
raw_urls = []
for link in soup.find_all('a'):          
    raw_urls.append(link.get('href'))
raw_urls = list(raw_urls)
raw_urls
# Out:
# ['https://www.myloyalist.com',
#  'https://www.loyalistcollege.com',
#  '/future-students/book-a-visit/',
#  '#',
#  '#',
#  '/programs-and-courses/full-time-programs',
#  '/programs-and-courses/full-time-programs',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/',
#  'https://www.loyalistcollege.com/programs-and-courses/january-program-starts/',
#  'https://www.loyalistcollege.com/programs-and-courses/post-graduate-programs/',
#  'https://www.loyalistcollege.com/focus/',
#  'https://www.loyalistcollege.com/programs-and-courses/apprenticeships/',
#  '/programs-and-courses/full-time-programs/career-and-college-prep/',
#  'https://www.loyalistbanner.com/PROD/cewkcrss.P_IndexPage#new_tab',
#  'https://www.loyalistcollege.com/programs-and-courses/elab/',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/general-education-electives/',
#  'https://www.loyalistcollege.com/programs-and-courses/justice-studies/',
#  '/programs-and-courses/training-and-certification',
#  '/programs-and-courses/training-and-certification',
#  'http://www.loyalistcollege.com/our-campus/campus-facilities/digital-media-centre/',
#  'https://www.loyalistcollege.com/programs-and-courses/health-human-studies/',
#  'https://www.loyalistcollege.com/programs-and-courses/second-career/',
#  'https://www.loyalistcollege.com/programs-and-courses/skilled-trades-and-technology/',
#  'https://www.loyalistcollege.com/programs-and-courses/university-transfer-agreements-2/',
#  'http://www.loyalistcollege.com/programs-and-courses/full-time-programs/dual-credit/',
#  'https://www.loyalistcollege.com/programs-and-courses/your-path-your-future/',
#  'https://www.loyalistcollege.com/future-students/',
#  'https://www.loyalistcollege.com/future-students/',
#  'https://www.loyalistcollege.com/current-students/academic-schedule/',
#  '/how-to-apply/',
#  'https://www.loyalistcollege.com/congratulations-on-your-offer-of-admission/',
#  'https://www.loyalistcollege.com/current-students/wellness-at-loyalist/orientation_homepage/',
#  'https://www.loyalistcollege.com/indigenous-services/',
#  'http://www.loyalistcollege.com/future-students/summer-information-session-registration/',
#  'https://www.loyalistcollege.com/future-students/new-student-checklist/',
#  'https://www.loyalistcollege.com/current-students/student-success-services/international-students/',
#  'https://www.loyalistcollege.com/future-students/paying-for-college/',
#  'https://www.loyalistcollege.com/future-students/advanced-standing-options/',
#  'https://www.loyalistcollege.com/our-campus/residence/',
#  'https://www.loyalistcollege.com/future-students/prior-learning-assessment-and-recognition/',
#  'https://www.loyalistcollege.com/current-students/student-success-services/',
#  'https://www.loyalistcollege.com/future-students/why-choose-loyalist/',
#  'https://www.loyalistcollege.com/current-students/campus-life/',
#  '/future-students/book-a-visit/',
#  'https://www.loyalistcollege.com/future-students/student-life/',
#  'https://www.loyalistcollege.com/programs-and-courses/skilled-trades-and-technology/',
#  'https://www.loyalistcollege.com/future-students/quinte-skyhawks/',
#  'https://www.loyalistcollege.com/current-students/',
#  'https://www.loyalistcollege.com/current-students/',
#  'https://www.loyalistcollege.com/current-students/spring-2022-program-delivery/',
#  'https://www.loyalistcollege.com/current-students/academic-schedule/',
#  'https://loyalistcatl.ca/student-remote-learning-kit/#new_tab',
#  'https://www.loyalistcollege.com/about-loyalist/policies/',
#  'http://www.loyalistlancers.com#new_tab',
#  '/current-students/campus-life/',
#  'https://www.loyalistcollege.com/indigenous-services/',
#  'https://www.loyalistcollege.com/current-students/emergency-response-plan/',
#  'https://www.loyalistcollege.com/current-students/wellness-at-loyalist/',
#  'http://www.loyalistcollege.com/current-students/health-services/',
#  'http://www.loyalistlibrary.com/',
#  'https://www.loyalistcollege.com/future-students/paying-for-college/tuition-and-fees/',
#  'https://www.loyalistcollege.com/current-students/student-forms/',
#  'https://loyalistlife.com/who-we-are',
#  'https://www.loyalistcollege.com/current-students/student-success-services/',
#  'https://www.loyalistcollege.com/current-students/technology-services/',
#  'https://www.loyalistcollege.com/current-students/student-success-services/the-career-centre/',
#  'https://www.loyalistcollege.com/alumni/transcripts-tax-receipts/',
#  'https://www.loyalistcollege.com/international/study-abroad/',
#  'https://www.loyalistcollege.com/international/',
#  'https://www.loyalistcollege.com/international/',
#  'https://www.loyalistcollege.com/international/how-to-apply/',
#  'https://www.loyalistcollege.com/international/welcome-to-loyalist-college-in-toronto/',
#  'https://www.loyalistcollege.com/international/future-international-students/',
#  'https://www.loyalistcollege.com/international/loyalist-college-in-india/',
#  'https://www.loyalistcollege.com/international/current-international-students/',
#  'https://www.loyalistcollege.com/international/abroad/',
#  'https://www.loyalistcollege.com/about-loyalist/policies/',
#  'https://www.loyalistcollege.com/current-students/student-success-services/international-students/study-abroad/',
#  'https://www.loyalistcollege.com/international/faq-international-students/',
#  'https://www.loyalistcollege.com/international/international-events-and-activities/',
#  'https://www.loyalistcollege.com/our-campus/',
#  'https://www.loyalistcollege.com/our-campus/',
#  'https://www.loyalistcollege.com/future-students/book-a-visit/',
#  'https://www.loyalistcollege.com/current-students/student-success-services/academic-centre-for-testing/',
#  'https://www.loyalistcollege.com/our-campus/bancroft-campus-services/',
#  'http://www.bkstr.com/loyaliststore/home/en',
#  'https://www.loyalistcollege.com/?page_id=32150',
#  'https://www.loyalistcollege.com/our-campus/campus-facilities/',
#  'https://www.loyalistcollege.com/our-campus/sexual-violence-awareness/',
#  'https://www.loyalistcollege.com/about-loyalist/news/',
#  'https://www.loyalistcollege.com/our-campus/campus-maps-and-directions/',
#  '/category/loyalist-in-the-news',
#  'https://www.loyalistcollege.com/our-campus/residence/',
#  'https://www.loyalistcollege.com/about-loyalist/policies/',
#  'https://www.loyalistcollege.com/about-loyalist/community/',
#  'http://resto213.com',
#  'https://www.loyalistcollege.com/about-loyalist/sustainability/',
#  'http://www.loyalistspa.com/#new_tab',
#  'https://www.loyalistcollege.com/our-campus/parking/',
#  'https://91x.fm',
#  'http://www.loyalistcollege.com/current-students/inclement-weather/',
#  'https://www.loyalistcollege.com/about-loyalist/research-services/',
#  '/future-students/book-a-visit/',
#  'https://www.loyalistcollege.com',
#  '/programs-and-courses/full-time-programs',
#  '/programs-and-courses/full-time-programs/',
#  '#',
#  'https://www.loyalistcollege.com/programs-and-courses/january-program-starts/',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/',
#  '/programs-and-courses/full-time-programs/career-and-college-prep/',
#  'https://www.loyalistcollege.com/programs-and-courses/apprenticeships/',
#  'https://www.loyalistcollege.com/programs-and-courses/justice-studies/',
#  'http://www.loyalistcollege.com/our-campus/campus-facilities/digital-media-centre/',
#  'https://www.loyalistcollege.com/programs-and-courses/health-human-studies/',
#  'https://www.loyalistcollege.com/programs-and-courses/skilled-trades-and-technology/',
#  'https://www.loyalistbanner.com/PROD/cewkcrss.P_IndexPage#new_tab',
#  'https://www.loyalistcollege.com/programs-and-courses/your-path-your-future/',
#  'https://www.loyalistcollege.com/programs-and-courses/training-and-certification/',
#  'https://www.loyalistcollege.com/programs-and-courses/university-transfer-agreements-2/',
#  'https://www.loyalistcollege.com/programs-and-courses/post-graduate-programs/',
#  'https://www.loyalistcollege.com/programs-and-courses/program-maps/',
#  'https://www.loyalistcollege.com/programs-and-courses/second-career/',
#  'https://www.loyalistcollege.com/programs-and-courses/elab/',
#  '/programs-and-courses/full-time-programs/general-education-courses/',
#  '/programs-and-courses/full-time-programs/dual-credit/',
#  'http://loyalisttraining.com/training/motorcycle-training/#new_tab',
#  'javascript:window.print()',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '#',
#  'javascript:void(0)',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '/programs-and-courses/full-time-programs/advanced-filmmaking-digital-content-creation',
#  '/programs-and-courses/full-time-programs/advertising-and-marketing-communications-creative-design',
#  '/programs-and-courses/full-time-programs/animation-and-game-development',
#  '/programs-and-courses/full-time-programs/architectural-technician',
#  '/programs-and-courses/full-time-programs/architectural-technician',
#  '/programs-and-courses/full-time-programs/artificial-intelligence-and-data-science',
#  '/programs-and-courses/full-time-programs/automotive-service-technician-apprenticeship',
#  '/programs-and-courses/full-time-programs/biotechnology',
#  '/programs-and-courses/full-time-programs/biotechnology',
#  '/programs-and-courses/full-time-programs/business',
#  '/programs-and-courses/full-time-programs/business-sales-and-marketing',
#  '/programs-and-courses/full-time-programs/business-accounting',
#  '/programs-and-courses/full-time-programs/business-accounting',
#  '/programs-and-courses/full-time-programs/cannabis-applied-science',
#  '/programs-and-courses/full-time-programs/care-of-vulnerable-populations',
#  '/programs-and-courses/full-time-programs/career-and-college-prep',
#  '/programs-and-courses/full-time-programs/carpentry-and-renovation-techniques',
#  '/programs-and-courses/full-time-programs/carpentry-and-renovation-techniques',
#  '/programs-and-courses/full-time-programs/chemical-engineering-technician',
#  '/programs-and-courses/full-time-programs/chemical-engineering-technician',
#  '/programs-and-courses/full-time-programs/child-and-youth-care',
#  '/programs-and-courses/full-time-programs/civil-engineering-technician',
#  '/programs-and-courses/full-time-programs/civil-engineering-technician',
#  '/programs-and-courses/full-time-programs/community-and-justice-services',
#  '/programs-and-courses/full-time-programs/community-integration-through-co-operative-education',
#  '/programs-and-courses/full-time-programs/computer-systems-technician',
#  '/programs-and-courses/full-time-programs/construction-engineering-technician',
#  '/programs-and-courses/full-time-programs/culinary-skills',
#  '/programs-and-courses/full-time-programs/culinary-skills',
#  '/programs-and-courses/full-time-programs/customs-border-services',
#  '/programs-and-courses/full-time-programs/cyber-security',
#  '/programs-and-courses/full-time-programs/developmental-services-worker',
#  '/programs-and-courses/full-time-programs/early-childhood-education',
#  '/programs-and-courses/full-time-programs/electrical-techniques',
#  '/programs-and-courses/full-time-programs/electrical-techniques',
#  '/programs-and-courses/full-time-programs/environmental-technician',
#  '/programs-and-courses/full-time-programs/environmental-technician',
#  '/programs-and-courses/full-time-programs/esthetics-and-spa-management',
#  '/programs-and-courses/full-time-programs/finance-and-analytics',
#  '/programs-and-courses/full-time-programs/financial-technology',
#  '/programs-and-courses/full-time-programs/fitness-and-health-promotion',
#  '/programs-and-courses/full-time-programs/general-arts-and-science',
#  '/programs-and-courses/full-time-programs/global-business-management',
#  '/programs-and-courses/full-time-programs/heating-refrigeration-and-air-conditioning-techniques',
#  '/programs-and-courses/full-time-programs/heating-refrigeration-and-air-conditioning-techniques',
#  '/programs-and-courses/full-time-programs/horticulture-technician-apprenticeship',
#  '/programs-and-courses/full-time-programs/human-resources-management',
#  '/programs-and-courses/full-time-programs/inspections-enforcement-safety-and-investigations',
#  '/programs-and-courses/full-time-programs/journalism-communications',
#  '/programs-and-courses/full-time-programs/manufacturing-engineering-technician',
#  '/programs-and-courses/full-time-programs/massage-therapy',
#  '/programs-and-courses/full-time-programs/mechanical-techniques',
#  '/programs-and-courses/full-time-programs/mechatronics',
#  '/programs-and-courses/full-time-programs/motive-power-fundamentals-parts-and-counter-personnel',
#  '/programs-and-courses/full-time-programs/motive-power-fundamentals-parts-and-counter-personnel',
#  '/programs-and-courses/full-time-programs/nursing-honours-bachelor-of-science',
#  '/programs-and-courses/full-time-programs/occupational-therapist-assistant-and-physiotherapist-assistant',
#  '/programs-and-courses/full-time-programs/paralegal',
#  '/programs-and-courses/full-time-programs/paramedic',
#  '/programs-and-courses/full-time-programs/personal-support-worker',
#  '/programs-and-courses/full-time-programs/personal-support-worker-accelerated',
#  '/programs-and-courses/full-time-programs/photojournalism',
#  '/programs-and-courses/full-time-programs/police-foundations',
#  '/programs-and-courses/full-time-programs/practical-nursing',
#  '/programs-and-courses/full-time-programs/pre-health-sciences-pathway-to-advanced-diplomas-and-degrees-pre-health-sciences-pathway-to-certificates-and-diplomas',
#  '/programs-and-courses/full-time-programs/pre-service-firefighter-education-training',
#  '/programs-and-courses/full-time-programs/project-management',
#  '/programs-and-courses/full-time-programs/public-relations-event-management',
#  '/programs-and-courses/full-time-programs/radiation-safety',
#  '/programs-and-courses/full-time-programs/radio',
#  '/programs-and-courses/full-time-programs/recreation-sport-and-leisure',
#  '/programs-and-courses/full-time-programs/rpn-bridge-semester-into-honours-bachelor-of-science-in-nursing',
#  '/programs-and-courses/full-time-programs/social-service-worker',
#  '/programs-and-courses/full-time-programs/sports-and-entertainment-sales-and-marketing',
#  '/programs-and-courses/full-time-programs/supply-chain-management-global-logistics',
#  '/programs-and-courses/full-time-programs/survey-engineering-technician',
#  '/programs-and-courses/full-time-programs/television-filmmaking-digital-content-creation',
#  '/programs-and-courses/full-time-programs/welding-techniques',
#  '/programs-and-courses/full-time-programs/welding-techniques',
#  'https://www.loyalistcollege.com/contact-us/',
#  'https://www.loyalistcollege.com/sitemap/',
#  'https://www.facebook.com/loyalistcollege',
#  'http://instagram.com/loyalistcollege',
#  'https://twitter.com/LoyalistCollege',
#  'https://www.youtube.com/user/goloyalist',
#  'https://www.linkedin.com/company/loyalist-college',
#  'https://www.loyalistcollege.com/about-loyalist/',
#  'https://www.loyalistcollege.com/about-loyalist/',
#  'http://www.loyalistcollege.com/wp-content/uploads/2016/08/Loyalist.AcademicPlan-1.pdf',
#  'https://www.loyalistcollege.com/wp-content/uploads/annual-report/',
#  'https://www.loyalistcollege.com/about-loyalist/our-mission/',
#  'https://www.loyalistcollege.com/wp-content/uploads/2019/08/Loyalist-College-Strategic-Plan-2025.pdf',
#  '/category/news-release',
#  'https://www.loyalistcollege.com/about-loyalist/policies/',
#  'https://www.loyalistcollege.com/about-loyalist/accessibility-and-aoda/',
#  'https://www.loyalistcollege.com/about-loyalist/research-services/',
#  'https://www.loyalistcollege.com/about-loyalist/news/',
#  'https://www.loyalistcollege.com/about-loyalist/community/',
#  'https://www.loyalistcollege.com/about-loyalist/the-loyalist-college-foundation/',
#  'https://www.loyalistcollege.com/about-loyalist/board-of-governors/',
#  'https://www.loyalistcollege.com/about-loyalist/sustainability/',
#  'https://www.loyalistcollege.com/about-loyalist/policies/sexual-assault-sexual-violence/',
#  'https://www.loyalistcollege.com/about-loyalist/procurement-services/',
#  'https://www.loyalistcollege.com/about-loyalist/share-the-air/',
#  'https://www.loyalistcollege.com/about-loyalist/privacy-and-legal/',
#  'http://www.loyalistcollege.com/programs-and-courses/skilled-trades-and-technology/#weston',
#  'https://www.loyalistcollege.com/employment/',
#  'https://www.loyalistcollege.com/employment/',
#  'https://www.loyalistcollege.com/employment/work-at-loyalist-2/',
#  'https://www.loyalistcollege.com/employment/recruitment-services-for-employers/',
#  'http://www.loyalistcollege.com/current-students/student-success-services/the-career-centre/',
#  'https://www.loyalistcollege.com/employment/grad-statistics/',
#  'https://www.loyalistcollege.com/employment/community-employment-services/',
#  'https://www.loyalistcollege.com/alumni/',
#  'https://www.loyalistcollege.com/alumni/',
#  'https://www.loyalistcollege.com/alumni/keep-in-touch/',
#  '/category/alumni-wall-of-fame/',
#  'https://www.loyalistcollege.com/alumni/loyalist-alumni-mentorship-program/',
#  'https://www.loyalistcollege.com/alumni/membership-benefits/',
#  'https://www.loyalistcollege.com/alumni/transcripts-tax-receipts/',
#  'https://www.loyalistcollege.com/?page_id=1649',
#  'https://www.loyalistcollege.com/alumni/give-back/',
#  'https://www.loyalistcollege.com/support-loyalist/',
#  'https://www.loyalistcollege.com/support-loyalist/donate-now/',
#  'https://www.loyalistcollege.com/support-loyalist/donate-now/',
#  'https://www.loyalistcollege.com/about-loyalist/the-loyalist-college-foundation/']

# %%
#take relevent urls
sub_urls = []
base = 'https://www.loyalistcollege.com'
pattern ='^\/programs-and-courses\/full-time-programs\/.+'
for link in raw_urls:
    if link != None:
        if re.search(pattern, link):
            sub_urls.append(base + link)
sub_urls = set(sub_urls)
sub_urls = list(sub_urls)
sub_urls.sort()

# %%
sub_urls
# Out:
# ['https://www.loyalistcollege.com/programs-and-courses/full-time-programs/advanced-filmmaking-digital-content-creation',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/advertising-and-marketing-communications-creative-design',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/animation-and-game-development',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/architectural-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/artificial-intelligence-and-data-science',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/automotive-service-technician-apprenticeship',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/biotechnology',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/business',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/business-accounting',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/business-sales-and-marketing',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/cannabis-applied-science',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/care-of-vulnerable-populations',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/career-and-college-prep',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/career-and-college-prep/',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/carpentry-and-renovation-techniques',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/chemical-engineering-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/child-and-youth-care',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/civil-engineering-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/community-and-justice-services',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/community-integration-through-co-operative-education',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/computer-systems-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/construction-engineering-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/culinary-skills',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/customs-border-services',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/cyber-security',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/developmental-services-worker',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/dual-credit/',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/early-childhood-education',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/electrical-techniques',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/environmental-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/esthetics-and-spa-management',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/finance-and-analytics',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/financial-technology',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/fitness-and-health-promotion',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/general-arts-and-science',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/general-education-courses/',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/global-business-management',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/heating-refrigeration-and-air-conditioning-techniques',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/horticulture-technician-apprenticeship',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/human-resources-management',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/inspections-enforcement-safety-and-investigations',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/journalism-communications',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/manufacturing-engineering-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/massage-therapy',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/mechanical-techniques',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/mechatronics',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/motive-power-fundamentals-parts-and-counter-personnel',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/nursing-honours-bachelor-of-science',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/occupational-therapist-assistant-and-physiotherapist-assistant',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/paralegal',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/paramedic',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/personal-support-worker',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/personal-support-worker-accelerated',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/photojournalism',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/police-foundations',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/practical-nursing',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/pre-health-sciences-pathway-to-advanced-diplomas-and-degrees-pre-health-sciences-pathway-to-certificates-and-diplomas',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/pre-service-firefighter-education-training',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/project-management',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/public-relations-event-management',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/radiation-safety',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/radio',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/recreation-sport-and-leisure',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/rpn-bridge-semester-into-honours-bachelor-of-science-in-nursing',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/social-service-worker',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/sports-and-entertainment-sales-and-marketing',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/supply-chain-management-global-logistics',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/survey-engineering-technician',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/television-filmmaking-digital-content-creation',
#  'https://www.loyalistcollege.com/programs-and-courses/full-time-programs/welding-techniques']

# %%
# extract text
text_content = [extract_text_from_single_web_page(url) for url in sub_urls]

# %%
text_content[0]
# Out:
# "Advanced Filmmaking – Digital Content Creation\n- Credential\nOne-year Ontario College Graduate Certificate\n- Start Date\nSeptember entry\n- Location\nBelleville Campus\nFind Your Career\nGain the knowledge and skills needed to find employment in the motion picture and video industry:\n- Film camera operator\n- Motion picture camera operator\n- Studio camera operator\n- Sound effects operator\n- Gaffer\n- Director\n- Assistant director\n- Production manager\n- Production department head\n- Business operator\nIs it for you?\nYou may enjoy filmmaking and digital content creation if you are the kind of person who:\n- Enjoys working on short-term projects\n- Likes to travel and work in a variety of locations\n- Keeps up-to-date with current industry equipment and new technologies\n- Recognizes the importance of marketing, networking, relationship building, interacting and collaborating with other industry professionals\n- Is a self-starter who enjoys being in control of their own earning potential\nExperiential learning\nExplore the basic aspects of interactive storytelling to create video productions for a range of audiences and effectively analyze issues and emerging trends affecting the evolution of film and digital content.\nThis hands-on, industry-driven program explores every aspect of filmmaking and digital content creation:\n- Advanced camera equipment operation used in digital video and high-definition television (HDTV) production.\n- Audio recording and post-production techniques for film, video and digital content creation projects in accordance with professional standards.\n- Development and evaluation of scriptwriting for film and digital content creation to meet project requirements.\n- Creative leadership for feature films and digital content creation projects to meet client needs.\n- In-depth knowledge and familiarity in working with Adobe Creative Cloud products.\n- Professional editing skills, digital file management and organizational skills.\n- Develop co-productions in accordance with domestic and international treaties.\n- Identify and create grant and fundraising proposals for Canadian and international film and television industry.\n- Distribute completed projects via Canadian and international film, video and web-based distribution systems.\n- Plan, schedule, budget and manage location sites for various types of film and digital content projects in accordance with safety, legal and professional standards.\nFinish your studies with a four-week field placement:\n- Placement possibilities include, but are not limited to, CBC, Bell TV, Rogers Sportsnet, TSN, Citytv, Canwest Global, CTV, Corus Entertainment, Blue Ant Media, Hughes Integration, Shaw Media, Evertz Microsystems, Ross Video, and many more.\nOutstanding faculty make the difference\n- Learn from a diverse, skilled and accessible faculty team with experience at Canada’s major broadcasters, production companies and international sporting events including the Olympic Games, the World Cup, NASCAR and the X Games.\n- Professors’ wide-ranging roles in the industry include: reporter; director; producer; camera person; graphics and motion graphics designer; director of photography; radio anchor; TV producer; documentary producer; production executive; broadcaster; writer; videographer; features producer; ENG editor; floor director; studio camera operator; and lighting director/designer.\n- Consultation with an advisory committee of national industry leaders ensures the program stays up-to-date with changes in this ever-evolving industry.\nCourses\n- First Year - Semester One\n- ADVF1002 Advanced Production Techniques 1\n- Students will develop a toolkit of production techniques in advanced areas of production. Sophisticated production, lighting, camera in departmental head roles.\n- ADVF1003 Cluster-Based Production 1\n- Using advanced content creation skills, students will pre-produce and produce stories for a range of community organizations and initiati ...

# %%
# json_txt = json.dumps(text_content, indent=2)
# Serializing json 
json_object = json.dumps(text_content, indent = 2)
  
# Writing to sample.json
with open("loyalist_colleges.json", "w") as outfile:
    outfile.write(json_object)

# %%
one_txt = extract_text_from_single_web_page("base_url")

# %%
# directory = "Scrapped_data"
# if not os.path.exists(directory):
#     os.mkdir(directory)
# with open(directory+"/"+"scrapped_loyalist_college.txt",'w') as file:
#     file.write(text_content)
